# %%
from super_gradients.training import models

yolo_nas_l = models.get("yolo_nas_l", pretrained_weights="coco")
# Out:
# The console stream is logged into C:\Users\neera\sg_logs\console.log
# [2023-06-07 21:51:51] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# [2023-06-07 21:51:52] WARNING - redirects.py - NOTE: Redirects are currently not supported in Windows or MacOs.
# C:\Users\neera\AppData\Roaming\Python\Python310\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: 'Could not find module 'C:\Users\neera\AppData\Roaming\Python\Python310\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# [2023-06-07 21:52:09] WARNING - __init__.py - Failed to import pytorch_quantization
# [2023-06-07 21:52:09] WARNING - calibrator.py - Failed to import pytorch_quantization
# [2023-06-07 21:52:09] WARNING - export.py - Failed to import pytorch_quantization
# [2023-06-07 21:52:09] WARNING - selective_quantization_utils.py - Failed to import pytorch_quantization
# [2023-06-07 21:52:10] WARNING - env_sanity_check.py - Failed to verify operating system: Deci officially supports only Linux kernels. Some features may not work as expected.
# [2023-06-07 21:52:11] INFO - checkpoint_utils.py - License Notification: YOLO-NAS pre-trained weights are subjected to the specific license terms and conditions detailed in
# https://github.com/Deci-AI/super-gradients/blob/master/LICENSE.YOLONAS.md
# By downloading the pre-trained weight files you agree to comply with these terms.
# Downloading: "https://sghub.deci.ai/models/yolo_nas_l_coco.pth" to C:\Users\neera/.cache\torch\hub\checkpoints\yolo_nas_l_coco.pth
# 100%|██████████| 256M/256M [00:09<00:00, 26.9MB/s]

# %%
# Import the YouTubeVideo class from IPython.display
from IPython.display import YouTubeVideo

# Define the YouTube video ID
video_id = 'aE8I7bDf62M'  # Replace YOUR_VIDEO_ID with the actual video ID

# Create a YouTubeVideo object with the specified video ID
video = YouTubeVideo(video_id)

# Display the video
display(video)

# %%
# Define the URL of the YouTube video
video_url = f'https://www.youtube.com/watch?v={video_id}'  

# Download the video in mp4 format
# !pip install -U "git+https://github.com/ytdl-org/youtube-dl.git"
# !python -m youtube_dl -f 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/mp4' "$video_url"

# Print a success message
print('Video downloaded successfully')

input_video_path = f"C:\\Neeraj\\Intel_OneAPI\\6 Reasons Why You Should Get a Dashcam.mp4"
output_video_path = "C:\\Neeraj\\Intel_OneAPI\\detections.mp4"
# Out:
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/ytdl-org/youtube-dl.git 'C:\Users\neera\AppData\Local\Temp\pip-req-build-eb6f0lg_'
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# Collecting git+https://github.com/ytdl-org/youtube-dl.git
#   Cloning https://github.com/ytdl-org/youtube-dl.git to c:\users\neera\appdata\local\temp\pip-req-build-eb6f0lg_
#   Resolved https://github.com/ytdl-org/youtube-dl.git to commit b8a86dcf1aa837577178ae25357d8241ab4ba6c1
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ERROR: requested format not available
# [youtube] aE8I7bDf62M: Downloading webpage
# Video downloaded successfully

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else "cpu"

# %%
yolo_nas_l.to(device).predict(input_video_path).save(output_video_path)
# Out:
# Predicting Video:   0%|          | 0/2297 [00:00<?, ?it/s][2023-06-07 22:18:01] INFO - pipelines.py - Fusing some of the model's layers. If this takes too much memory, you can deactivate it by setting `fuse_model=False`
# Predicting Video:   0%|          | 0/2297 [00:37<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 yolo_nas_l.to(device).predict(input_video_path).save(output_video_path)
#
# File c:\Python310\lib\site-packages\super_gradients\training\models\detection_models\customizable_detector.py:177, in CustomizableDetector.predict(self, images, iou, conf, fuse_model)
#     168 """Predict an image or a list of images.
#     169
#     170 :param images:  Images to predict.
#    (...)
#     174 :param fuse_model: If True, create a copy of the model, and fuse some of its layers to increase performance. This increases memory usage.
#     175 """
#     176 pipeline = self._get_pipeline(iou=iou, conf=conf, fuse_model=fuse_model)
# --> 177 return pipeline(images)
#
# File c:\Python310\lib\site-packages\super_gradients\training\pipelines\pipelines.py:94, in Pipeline.__call__(self, inputs, batch_size)
#      79 """Predict an image or a list of images.
#      80
#      81 Supported types include:
#    (...)
#      90 :return:            Results of the prediction.
#      91 """
#      93 if includes_video_extension(inputs):
# ---> 94     return self.predict_video(inputs, batch_size)
#      95 elif check_image_typing(inputs):
#      96     return self.predict_images(inputs, batch_size)
#
# File c:\Python310\lib\site-packages\super_gradients\training\pipelines\pipelines.py:122, in Pipeline.predict_video(self, video_path, batch_size)
#     120 video_frames, fps = load_video(file_path=video_path)
#     121 result_generator = self._generate_prediction_result(images=video_frames, batch_size=batch_size)
# --> 122 return self._combine_image_prediction_to_video(result_generator, fps=fps, n_images=len(video_frames))
#
# File c:\Python310\lib\site-packages\super_gradients\training\pipelines\pipelines.py:299, in DetectionPipeline._combine_image_prediction_to_video(self, images_predictions, fps, n_images)
#     296 def _combine_image_prediction_to_video(
#     297     self, images_predictions: Iterable[ImageDetectionPrediction], fps: float, n_images: Optional[int] = None
#     298 ) -> VideoDetectionPrediction:
# --> 299     images_predictions = [image_predictions for image_predictions in tqdm(images_predictions, total=n_images, desc="Predicting Video")]
#     300     return VideoDetectionPrediction(_images_prediction_lst=images_predictions, fps=fps)
#
# File c:\Python310\lib\site-packages\super_gradients\training\pipelines\pipelines.py:299, in <listcomp>(.0)
#     296 def _combine_image_prediction_to_video(
#     297     self, images_predictions: Iterable[ImageDetectionPrediction], fps: float, n_images: Optional[int] = None
#     298 ) -> VideoDetectionPrediction:
# --> 299     images_predictions = [image_predictions for image_predictions in tqdm(images_predictions, total=n_images, desc="Predicting Video")]
#     300     return VideoDetectionPrediction(_images_prediction_lst=images_predictions, fps=fps)
#
# File c:\Python310\lib\site-packages\tqdm\std.py:1178, in tqdm.__iter__(self)
#    1175 time = self._time
#    1177 try:
# -> 1178     for obj in iterable:
#    1179         yield obj
#    1180         # Update and possibly print the progressbar.
#    1181         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Python310\lib\site-packages\super_gradients\training\pipelines\pipelines.py:149, in Pipeline._generate_prediction_result(self, images, batch_size)
#     147 else:
#     148     for batch_images in generate_batch(images, batch_size):
# --> 149         yield from self._generate_prediction_result_single_batch(batch_images)
#
# File c:\Python310\lib\site-packages\super_gradients\training\pipelines\pipelines.py:177, in Pipeline._generate_prediction_result_single_batch(self, images)
#     175         self._fuse_model(torch_inputs)
#     176     model_output = self.model(torch_inputs)
# --> 177     predictions = self._decode_model_output(model_output, model_input=torch_inputs)
#     179 # Postprocess
#     180 postprocessed_predictions = []
#
# File c:\Python310\lib\site-packages\super_gradients\training\pipelines\pipelines.py:264, in DetectionPipeline._decode_model_output(self, model_output, model_input)
#     257 def _decode_model_output(self, model_output: Union[List, Tuple, torch.Tensor], model_input: np.ndarray) -> List[DetectionPrediction]:
#     258     """Decode the model output, by applying post prediction callback. This includes NMS.
#     259
#     260     :param model_output:    Direct output of the model, without any post-processing.
#     261     :param model_input:     Model input (i.e. images after preprocessing).
#     262     :return:                Predicted Bboxes.
#     263     """
# --> 264     post_nms_predictions = self.post_prediction_callback(model_output, device=self.device)
#     266     predictions = []
#     267     for prediction, image in zip(post_nms_predictions, model_input):
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Python310\lib\site-packages\super_gradients\training\models\detection_models\pp_yolo_e\post_prediction_callback.py:65, in PPYoloEPostPredictionCallback.forward(self, outputs, device)
#      62     pred_bboxes = pred_bboxes[topk_candidates.indices, :]
#      64 # NMS
# ---> 65 idx_to_keep = torchvision.ops.boxes.batched_nms(boxes=pred_bboxes, scores=pred_cls_conf, idxs=pred_cls_label, iou_threshold=self.nms_threshold)
#      67 pred_cls_conf = pred_cls_conf[idx_to_keep].unsqueeze(-1)
#      68 pred_cls_label = pred_cls_label[idx_to_keep].unsqueeze(-1)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torchvision\ops\boxes.py:75, in batched_nms(boxes, scores, idxs, iou_threshold)
#      73     return _batched_nms_vanilla(boxes, scores, idxs, iou_threshold)
#      74 else:
# ---> 75     return _batched_nms_coordinate_trick(boxes, scores, idxs, iou_threshold)
#
# File c:\Python310\lib\site-packages\torch\jit\_trace.py:1220, in _script_if_tracing.<locals>.wrapper(*args, **kwargs)
#    1216 @functools.wraps(fn)
#    1217 def wrapper(*args, **kwargs):
#    1218     if not is_tracing():
#    1219         # Not tracing, don't do anything
# -> 1220         return fn(*args, **kwargs)
#    1222     compiled_fn = script(wrapper.__original_fn)  # type: ignore[attr-defined]
#    1223     return compiled_fn(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torchvision\ops\boxes.py:94, in _batched_nms_coordinate_trick(boxes, scores, idxs, iou_threshold)
#      92 offsets = idxs.to(boxes) * (max_coordinate + torch.tensor(1).to(boxes))
#      93 boxes_for_nms = boxes + offsets[:, None]
# ---> 94 keep = nms(boxes_for_nms, scores, iou_threshold)
#      95 return keep
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torchvision\ops\boxes.py:40, in nms(boxes, scores, iou_threshold)
#      38 if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#      39     _log_api_usage_once(nms)
# ---> 40 _assert_has_ops()
#      41 return torch.ops.torchvision.nms(boxes, scores, iou_threshold)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torchvision\extension.py:48, in _assert_has_ops()
#      46 def _assert_has_ops():
#      47     if not _has_ops():
# ---> 48         raise RuntimeError(
#      49             "Couldn't load custom C++ ops. This can happen if your PyTorch and "
#      50             "torchvision versions are incompatible, or if you had errors while compiling "
#      51             "torchvision from source. For further information on the compatible versions, check "
#      52             "https://github.com/pytorch/vision#installation for the compatibility matrix. "
#      53             "Please check your PyTorch version with torch.__version__ and your torchvision "
#      54             "version with torchvision.__version__ and verify if they are compatible, and if not "
#      55             "please reinstall torchvision so that it matches your PyTorch install."
#      56         )
#
# RuntimeError: Couldn't load custom C++ ops. This can happen if your PyTorch and torchvision versions are incompatible, or if you had errors while compiling torchvision from source. For further information on the compatible versions, check https://github.com/pytorch/vision#installation for the compatibility matrix. Please check your PyTorch version with torch.__version__ and your torchvision version with torchvision.__version__ and verify if they are compatible, and if not please reinstall torchvision so that it matches your PyTorch install.
